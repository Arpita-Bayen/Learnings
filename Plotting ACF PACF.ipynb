# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
df=pd.read_csv('Shoe-Sales (1).csv')

# %%
plot_acf(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20860\2374180915.py in <module>
# ----> 1 plot_acf(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     211                     raise TypeError(msg)
#     212                 kwargs[new_arg_name] = new_arg_value
# --> 213             return func(*args, **kwargs)
#     214
#     215         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, adjusted, fft, missing, title, zero, auto_ylims, bartlett_confint, vlines_kwargs, **kwargs)
#     214     confint = None
#     215     # acf has different return type based on alpha
# --> 216     acf_x = acf(
#     217         x,
#     218         nlags=nlags,
#
# ...

# %% [markdown]
# I need only the shoe sales column

# %%
df['YearMonth']=pd.to_datetime(df['YearMonth'])

# %%
plot_acf(df['Shoe_Sales'])
plt.show();

# %%
df1=pd.read_csv('Shoe-Sales (1).csv',index_col=0)

# %%
df1
# Out:
#            Shoe_Sales
# YearMonth
# 1980-01            85
# 1980-02            89
# 1980-03           109
# 1980-04            95
# 1980-05            91
# ...               ...
# 1995-03           188
# 1995-04           195
# 1995-05           189
# 1995-06           220
# 1995-07           274
#
# [187 rows x 1 columns]

# %%
df2=pd.read_csv('Shoe-Sales (1).csv',header=0)

# %%
df2
# Out:
#     YearMonth  Shoe_Sales
# 0     1980-01          85
# 1     1980-02          89
# 2     1980-03         109
# 3     1980-04          95
# 4     1980-05          91
# ..        ...         ...
# 182   1995-03         188
# 183   1995-04         195
# 184   1995-05         189
# 185   1995-06         220
# 186   1995-07         274
#
# [187 rows x 2 columns]

# %%
df3=pd.read_csv('Shoe-Sales (1).csv',header=0,index_col=0)

# %%
df3
# Out:
#            Shoe_Sales
# YearMonth
# 1980-01            85
# 1980-02            89
# 1980-03           109
# 1980-04            95
# 1980-05            91
# ...               ...
# 1995-03           188
# 1995-04           195
# 1995-05           189
# 1995-06           220
# 1995-07           274
#
# [187 rows x 1 columns]

# %% [markdown]
# the first column is the index column by passing index_col=0:

# %%
plot_acf(df3)
plt.show();

# %% [markdown]
# For Showing 10 lags

# %%
plot_acf(df3,lags=10)
plt.show();

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(df3,lags=50)
plt.show();
